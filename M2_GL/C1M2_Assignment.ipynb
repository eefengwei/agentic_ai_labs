# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import unittests
#
# File ~/Documents/projects/agentic_ai_lesson/M2/M2_graded/unittests.py:1
# ----> 1 from dlai_grader.grading import test_case, print_feedback
#       2 from types import FunctionType
#       4 # Neutral inputs
#
# ModuleNotFoundError: No module named 'dlai_grader'

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an essay writing assistant. Given an essay topic: {topic}
    Please write a complete essay and ONLY output the essay content strings.
    Requirements:
    - The essay should not be too short and its length should be more than 100.
    
    """.strip()

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %%
print(generate_draft("aiagent"))
# Out:
# Artificial Intelligence Agents: Transforming the Future
#
# Artificial Intelligence (AI) agents are rapidly advancing, impacting numerous sectors and reshaping the landscape of technological advancements. These sophisticated systems are designed to perceive their environment and take actions, autonomously or semi-autonomously, to achieve specific goals. From simple virtual assistants on our smartphones to complex decision-making programs in healthcare and finance, AI agents are becoming an integral part of our daily lives, driving efficiency and innovation.
#
# AI agents are powered by algorithms that enable them to learn from data, recognize patterns, and make informed decisions. They can perform tasks ranging from mundane to highly complex with significant speed and accuracy. In the realm of customer service, for example, AI agents are deployed to handle inquiries, troubleshoot problems, and engage with customers in real-time, providing instant solutions and improving user satisfaction. Similarly, AI agents in healthcare analyze medical data to assist doctors in diagnosing diseases, prescribing treatments, and predicting patient outcomes, thus augmenting the capabilities of healthcare providers and enhancing patient care.
#
# Moreover, AI agents are assisting in environmental conservation efforts by monitoring ecosystems through data collected via sensors and satellites. They process this data to track wildlife, detect illegal activities, and analyze environmental changes, thus enabling timely interventions and policy planning. In finance, AI agents are employed for fraud detection, algorithmic trading, and personalized financial advice, thus transforming traditional financial operations into highly efficient and secure processes.
#
# Despite the numerous advantages, the rise of AI agents presents challenges and ethical considerations. Issues related to data privacy, algorithmic bias, and the potential displacement of jobs due to automation require careful consideration. Ensuring that AI agents are designed and deployed responsibly, with transparency and fairness in mind, is crucial to maximize their benefits while minimizing risks.
#
# In conclusion, AI agents are a testament to human ingenuity, providing powerful tools that enhance capabilities and drive progress across various domains. As we continue to innovate and integrate these systems into society, it is vital to address the ethical and practical challenges they present. By doing so, we can harness the full potential of AI agents to create a future that is more efficient, sustainable, and equitable for all.

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You're an essay reviewer. Given a draft essay content: {draft}, please
    review this essay and give your feedbacks. 
    ONLY return a string with feedback in paragraph form.
    Requirements:
    - The feedback should be critical but constructive.
    - It should address issues such as structure, clarity, strength of argument, and writing style.
    """.strip()

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %%
draft_essay = generate_draft("aiagent")
print(f'{draft_essay}')

print(f'-------')

feedback = reflect_on_draft(draft_essay)
print(feedback)
# Out:
# Artificial Intelligence Agents: Transforming the Future
#
# Artificial Intelligence (AI) has become one of the most transformative technologies of the 21st century, with AI agents playing a pivotal role in shaping various aspects of modern life. An AI agent can be described as a software entity that performs tasks autonomously, using data to make decisions, learn from experiences, and adapt to new situations. From personal assistants like Siri and Alexa to complex systems driving autonomous vehicles, AI agents are revolutionizing the way humans interact with technology.
#
# One of the primary advantages of AI agents is their ability to process vast amounts of data at incredible speeds. In fields such as healthcare, for example, AI agents can analyze medical records and diagnostic imaging to support doctors in diagnosing diseases and suggesting personalized treatment plans. By identifying patterns that might be missed by the human eye, AI agents contribute to more accurate diagnoses and better patient outcomes.
#
# In the corporate world, AI agents are proving invaluable by optimizing operations and enhancing decision-making. Businesses utilize AI agents to streamline supply chains, personalize customer experiences, and forecast market trends. An AI agent can analyze consumer behavior, enabling companies to tailor their marketing strategies effectively and efficiently. This level of insight allows businesses to remain competitive in fast-paced markets, ultimately increasing profitability and sustainability.
#
# Education is another arena where AI agents are making significant impacts. Educational AI agents can provide personalized learning experiences, adapting to the unique pace and style of each student. By analyzing students' performance data, these agents can recommend resources and exercises suited to individual needs, ensuring a more supportive and effective learning environment.
#
# Despite their many advantages, the deployment of AI agents also raises important ethical and practical concerns. Issues such as data privacy, algorithmic bias, and the potential for job displacement have generated significant debate. As AI agents become increasingly autonomous, questions surrounding accountability and decision transparency become more pertinent. Society must address these challenges by establishing robust ethical guidelines and regulatory frameworks to ensure AI agents are developed and used responsibly.
#
# In conclusion, AI agents are undoubtedly catalysts for change in a wide array of industries. Their ability to analyze data, learn, and make decisions is driving progress in fields ranging from healthcare to education. However, to harness the full potential of AI agents, it is crucial to navigate the ethical and societal implications they bring with them. As we continue to innovate and integrate AI agents into our lives, thoughtful consideration and responsible oversight will be essential in shaping a future where these technologies can coexist with human values and aspirations.
# -------
# The essay presents a clear and logical overview of AI agents’ applications across healthcare, business, and education, but it would benefit from tighter structuring and more specific evidence to strengthen its arguments. Although each paragraph follows a consistent pattern—introducing a domain, outlining AI’s benefits, and offering a brief illustration—the examples remain somewhat generic; integrating concrete case studies or statistics (for instance, quantifying diagnostic improvements in healthcare or citing user-adoption metrics for educational platforms) would lend greater authority. Transitions between sections are serviceable but occasionally feel formulaic, so varying your connective language could improve the essay’s flow. The discussion of ethical concerns is timely yet cursory; expanding on how particular regulatory frameworks or ethical guidelines might address data privacy or bias would deepen that analysis and demonstrate critical engagement. Finally, while the writing is generally clear and accessible, it leans on familiar phrasing and passive constructions—revising for active voice and more dynamic vocabulary will enhance readability and stylistic impact.

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an essay reviser. You are given the original draft essay: {original_draft} and
    the feedback:{reflection} from a essay reviewer. Please revise the essay according to 
    the feedback.
    Please return a string ONLY containing the revised and improved essay.
    Requirements:
    - The revised draft should address the issues mentioned in the feedback.
    - It should improve clarity, coherence, argument strength, and overall flow.
    - The function should use the feedback to guide the revision, and return only the final revised essay.  
    - The essay should not be too short and its length should be more than 100.
    """.strip()

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# In the contemporary digital age, social media platforms have become integral to daily life for millions across the globe. As these platforms continue to expand in influence and reach, the question of whether they should be regulated by the government has emerged as a pressing topic of debate. The potential for both positive and negative impacts of government regulation on social media necessitates a nuanced consideration of its benefits and drawbacks.
#
# On one hand, the regulation of social media by the government could enhance user protection and ensure a safer online environment. The plethora of content available on these platforms includes harmful elements such as misinformation, hate speech, and cyberbullying. Government intervention could help establish standards for what constitutes acceptable content, obliging platforms to implement stricter checks to curtail vile and misleading information. Moreover, regulation could ensure that user data is protected, mandating transparency in data collection practices and the enforcement of robust privacy protections that would safeguard individuals' personal information.
#
# However, while the protective capabilities of regulation are compelling, potential drawbacks must also be considered. One significant concern is the threat to freedom of speech. Overregulation could lead to censorship, where the government dictates what can and cannot be expressed on social media. This could stifle creativity, limit open discourse, and impinge on individual rights to free expression. Furthermore, there is a risk of regulatory overreach wherein governments may leverage their power to suppress dissent or opposition, using regulation as a tool for political control rather than public interest.
#
# Additionally, the dynamic and rapidly evolving nature of social media presents challenges for implementing effective regulation. Legislation often lags behind technological advancements, raising concerns that government-imposed regulations might quickly become outdated or struggle to keep up with innovative developments in the digital sphere. This lag could result in ineffective policies that neither address current issues nor anticipate future ones.
#
# In weighing these considerations, it becomes evident that while government regulation could address some of the inherent issues within social media platforms, it is not without significant risks. Perhaps a balanced approach, involving a combination of government oversight and self-regulation by platforms, would better address the complexities of this issue. Collaborative efforts between governments, social media companies, and civil society could lead to frameworks that protect users without unduly restricting freedom, ensuring that social media can continue to be a platform for positive engagement and expression.
#
# In conclusion, the question of whether social media platforms should be regulated by the government is complex and multifaceted, demanding careful consideration of potential benefits and pitfalls. Regulation has the capacity to protect users and ensure data privacy, but also threatens freedom of expression and may lag behind technological changes. A balanced, collaborative approach might offer a viable pathway, safeguarding the advantages of social media while mitigating its risks. Such an approach would require ongoing dialogue, adaptation, and vigilance to navigate the ever-changing landscape of the digital age.
#
# 🧠 Feedback:
#
# The essay presents a clear, balanced exploration of the debate over government regulation of social media, but it would benefit from stronger structural signposts and more concrete examples to support its claims. While the introduction effectively frames the issue’s relevance, it reads a bit generally—consider opening with a surprising statistic or a brief anecdote to draw readers in more forcefully. The body paragraphs each address a distinct perspective, yet they tend toward abstraction; weaving in specific case studies (for instance, a recent data‐privacy scandal or an example of controversial content removal) would lend greater authority to your analysis. Transitions between ideas are smooth but could be sharpened by explicitly tying each drawback or benefit back to your central thesis, ensuring the reader consistently sees how each point advances your overall argument. Your discussion of potential solutions is thoughtful, yet it remains somewhat broad—outlining what a “balanced approach” might look like in practice (e.g., a joint oversight board, phased regulatory trials) would give your conclusion more weight. In terms of style, your tone is appropriately measured, but varying sentence length and introducing a rhetorical question or two could enliven the prose. Finally, the conclusion aptly summarizes the core tensions but could be strengthened by a call to action or a forward‐looking statement that underscores the urgency of continued dialogue. Overall, the essay is well organized and articulate, but it would become more persuasive and engaging with sharper examples, tighter linkage to the thesis, and a more vivid writing style.
#
# ✍️ Revised:
#
# In the contemporary digital age, social media platforms have become integral to daily life for millions across the globe, with users spending over 2 hours daily on these platforms. As these platforms continue to expand in influence and reach, the question of whether they should be regulated by the government has emerged as a pressing topic of debate. The potential for both positive and negative impacts of government regulation on social media necessitates a nuanced consideration of its benefits and drawbacks.
#
# One of the key arguments for government regulation of social media is the enhancement of user protection, creating a safer online environment. The sheer volume of content available on these platforms includes harmful elements such as misinformation, hate speech, and cyberbullying. For instance, the Cambridge Analytica scandal highlighted significant privacy concerns, where users' personal data was exploited without consent. Government intervention could help establish standards for what constitutes acceptable content, obliging platforms to implement stricter checks to curtail vile and misleading information. Moreover, regulation could ensure that user data is protected, mandating transparency in data collection practices and the enforcement of robust privacy protections that would safeguard individuals' personal information.
#
# However, while the protective capabilities of regulation are compelling, potential drawbacks must also be considered, foremost among which is the threat to freedom of speech. Overregulation could lead to censorship, where the government dictates what can and cannot be expressed on social media. This could stifle creativity, limit open discourse, and impinge on individual rights to free expression. A pertinent example is the controversial removal of content in some countries where governments leverage power to suppress dissent or opposition, using regulation more as a tool for political control than public interest.
#
# Additionally, the dynamic and rapidly evolving nature of social media presents challenges for implementing effective regulation. Legislation often lags behind technological advancements, raising concerns that government-imposed regulations might quickly become outdated or struggle to keep up with innovative developments in the digital sphere. This lag could result in ineffective policies that neither address current issues nor anticipate future ones.
#
# In weighing these considerations, it becomes evident that while government regulation could address some of the inherent issues within social media platforms, it is not without significant risks. A balanced approach might involve a combination of government oversight and self-regulation by platforms. Creating a joint oversight board or conducting phased regulatory trials could better address the complexities of this issue. Collaborative efforts between governments, social media companies, and civil society could lead to frameworks that protect users without unduly restricting freedom, ensuring that social media can continue to be a platform for positive engagement and expression.
#
# In conclusion, the question of whether social media platforms should be regulated by the government is complex and multifaceted, demanding careful consideration of potential benefits and pitfalls. Regulation has the capacity to protect users and ensure data privacy but also threatens freedom of expression and may lag behind technological changes. A balanced, collaborative approach might offer a viable pathway, safeguarding the advantages of social media while mitigating its risks. As we navigate this ever-changing digital landscape, it's crucial to maintain an ongoing dialogue, adaptation, and vigilance, ensuring that policy and practice keep pace with the rapid evolution of technology. The urgency of this issue cannot be understated—effective solutions will require collective foresight and proactive engagement from all stakeholders.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">In the contemporary digital age, social media platforms have become integral to daily life for millions across the globe. As these platforms continue to expand in influence and reach, the question of whether they should be regulated by the government has emerged as a pressing topic of debate. The potential for both positive and negative impacts of government regulation on social media necessitates a nuanced consideration of its benefits and drawbacks.
#
# On one hand, the regulation of social media by the government could enhance user protection and ensure a safer online environment. The plethora of content available on these platforms includes harmful elements such as misinformation, hate speech, and cyberbullying. Government intervention could help establish standards for what constitutes acceptable content, obliging platforms to implement stricter checks to curtail vile and misleading information. Moreover, regulation could ensure that user data is protected, mandating transparency in data collection practices and the enforcement of robust privacy protections that would safeguard individuals' personal information.
#
# However, while the protective capabilities of regulation are compelling, potential drawbacks must also be considered. One significant concern is the threat to freedom of speech. Overregulation could lead to censorship, where the government dictates what can and cannot be expressed on social media. This could stifle creativity, limit open discourse, and impinge on individual rights to free expression. Furthermore, there is a risk of regulatory overreach wherein governments may leverage their power to suppress dissent or opposition, using regulation as a tool for political control rather than public interest.
#
# Additionally, the dynamic and rapidly evolving nature of social media presents challenges for implementing effective regulation. Legislation often lags behind technological advancements, raising concerns that government-imposed regulations might quickly become outdated or struggle to keep up with innovative developments in the digital sphere. This lag could result in ineffective policies that neither address current issues nor anticipate future ones.
#
# In weighing these considerations, it becomes evident that while government regulation could address some of the inherent issues within social media platforms, it is not without significant risks. Perhaps a balanced approach, involving a combination of government oversight and self-regulation by platforms, would better address the complexities of this issue. Collaborative efforts between governments, social media companies, and civil society could lead to frameworks that protect users without unduly restricting freedom, ensuring that social media can continue to be a platform for positive engagement and expression.
#
# In conclusion, the question of whether social media platforms should be regulated by the government is complex and multifaceted, demanding careful consideration of potential benefits and pitfalls. Regulation has the capacity to protect users and ensure data privacy, but also threatens freedom of expression and may lag behind technological changes. A balanced, collaborative approach might offer a viable pathway, safeguarding the advantages of social media while mitigating its risks. Such an approach would require ongoing dialogue, adaptation, and vigilance to navigate the ever-changing landscape of the digital age.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">The essay presents a clear, balanced exploration of the debate over government regulation of social media, but it would benefit from stronger structural signposts and more concrete examples to support its claims. While the introduction effectively frames the issue’s relevance, it reads a bit generally—consider opening with a surprising statistic or a brief anecdote to draw readers in more forcefully. The body paragraphs each address a distinct perspective, yet they tend toward abstraction; weaving in specific case studies (for instance, a recent data‐privacy scandal or an example of controversial content removal) would lend greater authority to your analysis. Transitions between ideas are smooth but could be sharpened by explicitly tying each drawback or benefit back to your central thesis, ensuring the reader consistently sees how each point advances your overall argument. Your discussion of potential solutions is thoughtful, yet it remains somewhat broad—outlining what a “balanced approach” might look like in practice (e.g., a joint oversight board, phased regulatory trials) would give your conclusion more weight. In terms of style, your tone is appropriately measured, but varying sentence length and introducing a rhetorical question or two could enliven the prose. Finally, the conclusion aptly summarizes the core tensions but could be strengthened by a call to action or a forward‐looking statement that underscores the urgency of continued dialogue. Overall, the essay is well organized and articulate, but it would become more persuasive and engaging with sharper examples, tighter linkage to the thesis, and a more vivid writing style.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">In the contemporary digital age, social media platforms have become integral to daily life for millions across the globe, with users spending over 2 hours daily on these platforms. As these platforms continue to expand in influence and reach, the question of whether they should be regulated by the government has emerged as a pressing topic of debate. The potential for both positive and negative impacts of government regulation on social media necessitates a nuanced consideration of its benefits and drawbacks.
#
# One of the key arguments for government regulation of social media is the enhancement of user protection, creating a safer online environment. The sheer volume of content available on these platforms includes harmful elements such as misinformation, hate speech, and cyberbullying. For instance, the Cambridge Analytica scandal highlighted significant privacy concerns, where users' personal data was exploited without consent. Government intervention could help establish standards for what constitutes acceptable content, obliging platforms to implement stricter checks to curtail vile and misleading information. Moreover, regulation could ensure that user data is protected, mandating transparency in data collection practices and the enforcement of robust privacy protections that would safeguard individuals' personal information.
#
# However, while the protective capabilities of regulation are compelling, potential drawbacks must also be considered, foremost among which is the threat to freedom of speech. Overregulation could lead to censorship, where the government dictates what can and cannot be expressed on social media. This could stifle creativity, limit open discourse, and impinge on individual rights to free expression. A pertinent example is the controversial removal of content in some countries where governments leverage power to suppress dissent or opposition, using regulation more as a tool for political control than public interest.
#
# Additionally, the dynamic and rapidly evolving nature of social media presents challenges for implementing effective regulation. Legislation often lags behind technological advancements, raising concerns that government-imposed regulations might quickly become outdated or struggle to keep up with innovative developments in the digital sphere. This lag could result in ineffective policies that neither address current issues nor anticipate future ones.
#
# In weighing these considerations, it becomes evident that while government regulation could address some of the inherent issues within social media platforms, it is not without significant risks. A balanced approach might involve a combination of government oversight and self-regulation by platforms. Creating a joint oversight board or conducting phased regulatory trials could better address the complexities of this issue. Collaborative efforts between governments, social media companies, and civil society could lead to frameworks that protect users without unduly restricting freedom, ensuring that social media can continue to be a platform for positive engagement and expression.
#
# In conclusion, the question of whether social media platforms should be regulated by the government is complex and multifaceted, demanding careful consideration of potential benefits and pitfalls. Regulation has the capacity to protect users and ensure data privacy but also threatens freedom of expression and may lag behind technological changes. A balanced, collaborative approach might offer a viable pathway, safeguarding the advantages of social media while mitigating its risks. As we navigate this ever-changing digital landscape, it's crucial to maintain an ongoing dialogue, adaptation, and vigilance, ensuring that policy and practice keep pace with the rapid evolution of technology. The urgency of this issue cannot be understated—effective solutions will require collective foresight and proactive engagement from all stakeholders.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
